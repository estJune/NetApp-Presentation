# %% [markdown]
# # Jupyter Notebook and Google Colab
#
# Today, we are going to use what have learned on Pokemon! But before we dive into that, let's discuss Google Colab and Jupyter Notebook. Juptyer Notebook is an interactive console for you to run your programs over the web or locally on your computer. Google Colab is a website that hosts your Jupyter Notebook programs for your to run. Imagine Jupyter Notebooks is the tool you use to write your program and Google Colab is the thing that runs your program on the web. So the following Python program is in a Juptyer Notebook and is executed by Google Colab. To execute, click on the play button the top left corener of the code block.
#
# (Note: Jupyter does have an AI assistance tool but I would prefer you don't use it so that you can better learn. Obviously, won't force you to not use it, so it is up to you. To turn it off, go to Settings->Editor and uncheck "Show context-powered code completions" and in Settings->AI Assistance and uncheck "Show AI-powered inline completions")

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# # Python References
#
# *   Basic Operations
# *   Control Flow
# *   Loops
# *   Functions
# *   Lists

# %%
# Assignment Operator
x = 10
y = 3

# Arithmetic Operators
print("Add:", x + y)
print("Subtract:", x - y)
print("Multiply:", x * y)
print("Divide:", x / y)
print("Modulus:", x % y)

# Comparison Operators
print("Equal:", x == y)
print("Not Equal:", x != y)
print("Greater:", x > y)
print("Less or Equal:", x <= y)

# If Statements
trending = True
views = 5000000

if trending:
    print("This video is trending!")
elif views > 1000000:
    print("This video is popular!")
else:
    print("Keep trying!")

# For Loops
for i in range(5):
    print("Number: ", i)

# While Loops
count = 0
while count < 3:
    print("Counting:", count)
    count += 1

# Lists
categories = ["Music", "Gaming", "News"]

for category in categories:
    print("Category:", category)

# Logical Operators
is_music = categories[0] == "Music"
is_gaming = categories[1] == "Gaming"
print("Music and Gaming:", is_music and is_gaming)
print("Music or Gaming:", is_music or is_gaming)


# Functions
def greet(channel):
    print("Hello,", channel)

greet("Tech Talk")
# Out:
# Add: 13
# Subtract: 7
# Multiply: 30
# Divide: 3.3333333333333335
# Modulus: 1
# Equal: False
# Not Equal: True
# Greater: True
# Less or Equal: False
# This video is trending!
# Number:  0
# Number:  1
# Number:  2
# Number:  3
# Number:  4
# Counting: 0
# Counting: 1
# Counting: 2
# Category: Music
# Category: Gaming
# Category: News
# Music and Gaming: True
# Music or Gaming: True
# Hello, Tech Talk

# %% [markdown]
# # Getting Started
#
# Since you guys are all hip and young, I’m going to assume you’ve at least heard of Pokémon, if not spent countless hours battling, collecting, or arguing about which starter is best (it’s not Charizard, fight me 😄).
#
# Ever wonder what makes some Pokémon so much stronger or more popular than others? Besides cool designs and type advantages, some Pokémon have seriously overpowered stats or killer move sets that make them stand out in battles, competitions, and memes alike.
#
# So maybe a Pokémon like Blissey, with its absurd HP, is way more useful in a support role than something flashier. Or maybe Eternatus-Eternamax, which looks like a space dragon that swallowed a black hole, dominates purely because of its raw stats. In short: understanding the stats, types, and moves of a Pokémon can help you make smarter decisions in battle—and gain an edge as a trainer.
#
# In this activity, we’ll use real Pokémon data to analyze things like which types are most common, which Pokémon are the fastest, and what kinds of abilities show up the most. Think of it like being a Pokédex researcher—just with Python instead of a lab coat.
#
# Let's look at the first 5 rows of the dataset...

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd

# Set the path to the file you'd like to load
file_path = "pokemon_data.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "tanishksharma9905/pokemon-data-csv",
  file_path,
)

# Convert comma separated string in the columns to lists
df["stats"] = pd.Series(df["stats"].str.split(","))
# Return dictionary for key=val being stat=val
def parse_series(series):
    return {kv.split('=')[0].strip(): kv.split('=')[1] for kv in series}
# Apply to the 'stats' column
expanded = df['stats'].apply(parse_series).apply(pd.Series)
# Convert values to numeric (optional but useful)
expanded = expanded.apply(pd.to_numeric, errors='coerce')
# Join with original DataFrame, dropping the original 'stats' column
df = pd.concat([df.drop(columns='stats'), expanded], axis=1)
# Drop the abilities column and the nan rows
df = df.drop("abilities", axis=1)
df = df.dropna()

df
# Out:
# /tmp/ipython-input-31-124497067.py:9: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
#          id                      name  base_experience  height  weight  \
# 0         1                 bulbasaur               64       7      69
# 1         2                   ivysaur              142      10     130
# 2         3                  venusaur              236      20    1000
# 3         4                charmander               62       6      85
# 4         5                charmeleon              142      11     190
# ...     ...                       ...              ...     ...     ...
# 1297  10273   ogerpon-wellspring-mask              275      12     398
# 1298  10274  ogerpon-hearthflame-mask              275      12     398
# 1299  10275  ogerpon-cornerstone-mask              275      12     398
# 1300  10276        terapagos-terastal               90       3     160
# ...

# %%
# First five rows
df.head()
# Out:
#    id        name  base_experience  height  weight          types  \
# 0   1   bulbasaur               64       7      69  grass, poison
# 1   2     ivysaur              142      10     130  grass, poison
# 2   3    venusaur              236      20    1000  grass, poison
# 3   4  charmander               62       6      85           fire
# 4   5  charmeleon              142      11     190           fire
#
#                                                moves  hp  attack  defense  \
# 0     razor-wind, swords-dance, cut, bind, vine-whip  45      49       49
# 1       swords-dance, cut, bind, vine-whip, headbutt  60      62       63
# 2       swords-dance, cut, bind, vine-whip, headbutt  80      82       83
# 3  mega-punch, fire-punch, thunder-punch, scratch...  39      52       43
# 4  mega-punch, fire-punch, thunder-punch, scratch...  58      64       58
#
#    special-attack  special-defense  speed
# 0              65               65     45
# ...

# %%
# Show only the id and name columns
df[["id", "name"]]
# Out:
#          id                      name
# 0         1                 bulbasaur
# 1         2                   ivysaur
# 2         3                  venusaur
# 3         4                charmander
# 4         5                charmeleon
# ...     ...                       ...
# 1297  10273   ogerpon-wellspring-mask
# 1298  10274  ogerpon-hearthflame-mask
# 1299  10275  ogerpon-cornerstone-mask
# 1300  10276        terapagos-terastal
# 1301  10277         terapagos-stellar
#
# [1268 rows x 2 columns]

# %%
# Top five pokemon with highest base_experience
df.sort_values(by="base_experience", ascending=False).head(5)
# Out:
#          id                 name  base_experience  height  weight  \
# 241     242              blissey              608      15     468
# 1214  10190  eternatus-eternamax              563    1000       0
# 1093  10069          audino-mega              425      15     320
# 112     113              chansey              395      11     346
# 530     531               audino              390      11     310
#
#                types                                              moves   hp  \
# 241           normal  pound, double-slap, mega-punch, fire-punch, ic...  255
# 1214  poison, dragon   fly, flamethrower, hyper-beam, solar-beam, toxic  255
# 1093   normal, fairy  pound, double-slap, fire-punch, ice-punch, thu...  103
# 112           normal  pound, double-slap, mega-punch, fire-punch, ic...  250
# 530           normal  pound, double-slap, mega-punch, fire-punch, ic...  103
#
#       attack  defense  special-attack  special-defense  speed
# ...

# %%
# Number pokemon with attack == 75
len(df[df["attack"] == 75])
# Out:
# 50

# %%
# Find the tallest height (not the pokemon)
df["height"].max()
# Out:
# 1000

# %%
# Which pokemon have the move fly
df[df["moves"].str.contains("fly")]
# Out:
#          id                         name  base_experience  height  weight  \
# 15       16                       pidgey               50       3      18
# 16       17                    pidgeotto              122      11     300
# 17       18                      pidgeot              216      15     395
# 20       21                      spearow               52       3      20
# 21       22                       fearow              155      12     380
# ...     ...                          ...              ...     ...     ...
# 1264  10240               braviary-hisui              179      17     434
# 1273  10249             enamorus-therian              116      16     480
# 1284  10260    squawkabilly-blue-plumage              146       6      24
# 1285  10261  squawkabilly-yellow-plumage              146       6      24
# 1286  10262   squawkabilly-white-plumage              146       6      24
#
#                 types                                              moves   hp  \
# ...

# %%
# Find the most attack power (not the pokemon)
df["attack"].max()
# Out:
# 190

# %%
# Find the pokemon with the most attack power
df[df["attack"] == df["attack"].max()]
# Out:
#          id           name  base_experience  height  weight  \
# 1067  10043  mewtwo-mega-x              351      23    1270
#
#                   types                                              moves  \
# 1067  psychic, fighting  pay-day, fire-punch, ice-punch, thunder-punch,...
#
#        hp  attack  defense  special-attack  special-defense  speed
# 1067  106     190      100             154              100    130

# %% [markdown]
# ## Task
#
# I want you to use Pandas to answer the following questions. Do your best, and we will review the answers in a little bit. I also recommend to play around a bit and come up with your own questions and attempt to answer them. Here is a reference link Pandas documentation, allowing you to see what other cool stuff Pandas offers you.
#
# https://pandas.pydata.org/docs/reference/index.html

# %%
# 1. How many Pokemon are in the dataset?

# %%
# 2. What is the heaviest pokemon?

# %%
# 3. Which Pokémon has the highest HP?

# %%
# 4. Which Pokemon has the highest speed?

# %%
# 5. How many Pokemon are fighting types?

# %%
# 6. What is the average base experience?

# %%
# 7. Find the top 5 pokemon that are the fastest?
